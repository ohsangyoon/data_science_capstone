# %% [markdown]
# # Introduction/Business Problem

# %% [markdown]
# ## Where should someone open a restauarnt in Seoul, South Korea to profit the most

# %% [markdown]
# Seoul is the capital and largest city in South Korea. Every day thousands of people venture throughout the city looking for the hottest trend of the time. Whether it be the latest hot restuaurant, cafe, or sensation going on the people of Korea tend to follow whichever business is picking up the most attention. Due to the nature of the city, it is very difficult to open a new business because there are numerous factors in whether it will suceed or not. Location, price, and competition all play a role in whether or not the business can suceed.
#
# Restaurants are something that Koreans are passionate about. As one of the top social media heavy countries in the world, Koreans flock to a restuarant that has many posts on Instagram, Facebook, and other social media websites. In order to be one of the places that many people flock to, it is important to consider numerous factors when deciding to open a new restaurant in Seoul.
#
# The factors that I will look into when deciding where to open a new restaurant will be the following:
#
# * Locate different districts within Seoul
# * Get geographical coordinates and map using Folium
# * Get types of venues within each district
# * Cluster neighborhoods using KNN to determine best one

# %% [markdown]
# # Data Portion

# %% [markdown]
# ## How will the data be gathered and analyzed to solve problem posed above

# %% [markdown]
# In order to solve this problem, the following data will be used:
#
# * Use Foursquare's API to chart districts
# * Use geolocater and folium to locate specific neighborhoods of Seoul
# * Use pandas to scrape data from websites
# * Clean data using various pandas techniques
# * Visualize them using folium maps
